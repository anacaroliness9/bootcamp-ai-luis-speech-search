# %% [markdown]
# # Step 2: Speech to Text with LUIS
#
# **Content**
#
# * Speech to Text with LUIS
#     * Summarizing the classification results
# * Saving transcriptions on json files

# %%
! pip install azure-cognitiveservices-speech
# Out:
# Collecting azure-cognitiveservices-speech
#   Downloading azure_cognitiveservices_speech-1.15.0-cp38-cp38-win_amd64.whl (1.6 MB)
# Installing collected packages: azure-cognitiveservices-speech
# Successfully installed azure-cognitiveservices-speech-1.15.0

# %%
from collections import Counter
import time
import ast
import json, re
from os import listdir
import sys
import os.path

# %%
import azure.cognitiveservices.speech as speechsdk
import os, yaml, time

# %% [markdown]
# Load Configs

# %%
config_file = os.path.join("config","config.yaml")
with open(config_file, 'r') as ymlfile:
    config = yaml.load(ymlfile, Loader=yaml.FullLoader)

##### Configurações do Speech:
speech_key=config['speech']['speech_key']
speech_service_region = config['speech']['speech_region']
language=config['speech']['speech_language']

##### Configurações do LUIS
luis_app_id=config['luis_app']['app_id']

# %% [markdown]
# ## Speech to Text com LUIS

# %% [markdown]
# Referências:
# * https://github.com/Azure-Samples/cognitive-services-speech-sdk/blob/master/samples/python/console/intent_sample.py

# %%
def recognize_intent_from_speech_continuous(speech_key, speech_service_region,luis_app_id, language, file_name):
    """Método para realizar o Speech to Text integrado ao LUIS, classificando cada fala do audio com as intenções"""
    result_json = {}
    result_json['result'] = []

    # <IntentContinuousRecognitionWithFile>
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=speech_service_region, speech_recognition_language=language)
    audio_config = speechsdk.audio.AudioConfig(filename=file_name)

    # Set up the intent recognizer
    intent_recognizer = speechsdk.intent.IntentRecognizer(speech_config=speech_config, audio_config=audio_config )

    # set up the intents that are to be recognized. These can be a mix of simple phrases and
    # intents specified through a LanguageUnderstanding Model.
    model = speechsdk.intent.LanguageUnderstandingModel(app_id=luis_app_id)
    intent_recognizer.add_all_intents(model)

    # Connect callback functions to the signals the intent recognizer fires.
    done = False

    def stop_cb(evt):
        """callback that signals to stop continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        if ('SessionEventArgs' in str(evt)):
            print ("ok")
            nonlocal done
            done = True
    
    intent_recognizer.recognized.connect(lambda evt: print(
        "RECOGNIZED: {}\n\tText: {} (Reason: {})\n\tIntent Id: {}\n\tIntent JSON: {}".format(
            evt, evt.result.text, evt.result.reason, evt.result.intent_id, evt.result.intent_json, result_json['result'].append(json.loads(evt.result.intent_json)))))
    
    # cancellation event
    intent_recognizer.canceled.connect(lambda evt: print("CANCELED: {} ({})".format(evt.cancellation_details, evt.reason)))

    # stop continuous recognition on session stopped, end of speech or canceled events
    intent_recognizer.session_stopped.connect(stop_cb)
    intent_recognizer.speech_end_detected.connect(stop_cb)
    intent_recognizer.canceled.connect(stop_cb)

    # And finally run the intent recognizer. The output of the callbacks should be printed to the console.
    intent_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    intent_recognizer.stop_continuous_recognition()
    
    # </IntentContinuousRecognitionWithFile>
    return result_json

# %%
def list_files(dir):
    '''Listar arquivos em um diretório específico no SO'''
    return [f for f in os.listdir(dir) if os.path.isfile(os.path.join(dir, f))]

# %%
def realizar_transcricao_plus_intencao( container_name,files_name=None):
    ''' Realizar a transcrição + classificação das inteções de todos os audios 
        ou somente de algum específico'''
    results = {}
    if (files_name is None):
        files_name = list_files(container_name)
    for f in files_name:
        print("Processando arquivo: {}.".format(f))
        results[f] = recognize_intent_from_speech_continuous(speech_key, speech_service_region,luis_app_id, language,os.path.join(container_name, f))
    return results

# %%
######## Teste para 1 arquivo ######## 
#results_json = realizar_transcricao_plus_intencao("audios", files_name=['id_5.wav'])

# %%
######## Teste para todos os arquivos ######## 
results_json = realizar_transcricao_plus_intencao("audios")
# Out:
#  De qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "de qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.964925051
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f, result=IntentRecognitionResult(result_id=789ce04a28504526a9710596460fbe63, text="São Paulo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Paulo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são paulo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.6789285
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f, result=IntentRecognitionResult(result_id=7093a29f67bd4fbbafe69c76e52b8878, text="Muito obrigada pelas informações você poderia anotar agora o número de protocolo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações você poderia anotar agora o número de protocolo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar agora o número de protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8974125
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f, result=IntentRecognitionResult(result_id=fb3b99d1537f4a78b344e0f5445216e2, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8653555
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f, result=IntentRecognitionResult(result_id=97875c07aabd45da99280dc0552e8ce0, text="É o número de protocolo é 540053287417.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: É o número de protocolo é 540053287417. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "é o número de protocolo é 540053287417",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.308178127
#   },
#   "entities": [
#     {
#       "entity": "540053287417",
#       "type": "protocolo",
#       "startIndex": 26,
#       "endIndex": 37,
#       "score": 0.7740497
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f, result=IntentRecognitionResult(result_id=6ec2c06a85804599bb55f330db269612, text="Irei encaminhar o seu caso para a área responsável e eles irão entrar em contato com você posso te ajudar em mais alguma coisa.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Irei encaminhar o seu caso para a área responsável e eles irão entrar em contato com você posso te ajudar em mais alguma coisa. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "irei encaminhar o seu caso para a área responsável e eles irão entrar em contato com você posso te ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8912635
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f, result=IntentRecognitionResult(result_id=820c5756360c4ac3bbe441a52c7c8f95, text="Não obrigada boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não obrigada boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9349111
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f, result=IntentRecognitionResult(result_id=a94c6930cd60450c9663c9e1ffb6182e, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.954223931
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# CLOSING on SessionEventArgs(session_id=369f63174ebb449aae566bcda77df77f)
# ok
# Processando arquivo: id_5.wav.
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=79338f344dec4eb1b5787f6f8e23bfb0, text="Boa tarde meu nome é Paulo para a seguradora e 6 em que eu posso te ajudar.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde meu nome é Paulo para a seguradora e 6 em que eu posso te ajudar. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde meu nome é paulo para a seguradora e 6 em que eu posso te ajudar",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8615547
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=2e38a20d33ba4598bb8a611f13570027, text="Olá Paula meu nome é Julia acabei de ser assaltada e roubaram meu carro.", intent_id=classe_roubo, reason=ResultReason.RecognizedIntent))
# 	Text: Olá Paula meu nome é Julia acabei de ser assaltada e roubaram meu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: classe_roubo
# 	Intent JSON: {
#   "query": "olá paula meu nome é julia acabei de ser assaltada e roubaram meu carro",
#   "topScoringIntent": {
#     "intent": "classe_roubo",
#     "score": 0.315209627
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=5ff335583ed143a5937b77d435b65b3a, text="Olá Julia eu preciso de algumas informações para registrar o seu sinistro tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Olá Julia eu preciso de algumas informações para registrar o seu sinistro tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "olá julia eu preciso de algumas informações para registrar o seu sinistro tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.947021067
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=cefba5cc1601473bbc8b49a4c9963546, text="Tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9542239
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=03117b3344c5479f85e589959378bd86, text="Poderia me informar a placa do seu carro.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me informar a placa do seu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me informar a placa do seu carro",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.934775531
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=b834580f347646fc8d588d6af3e9a1d6, text="ADR 2020.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: ADR 2020. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "ADR 2020",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.6789285
#   },
#   "entities": [
#     {
#       "entity": "adr 2020",
#       "type": "placa",
#       "startIndex": 0,
#       "endIndex": 7
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=f7d6244a97324fefa9bba7a94653da90, text="Poderia me passar o seu nome completo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar o seu nome completo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar o seu nome completo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9216928
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=266c603572cd47e88a01598e21bc07f6, text="Meu nome completo é Júlia Silvério.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu nome completo é Júlia Silvério. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu nome completo é júlia silvério",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.249826878
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=d01f7e1d1cb7429ca7d3da06d6ae912d, text="E qual seria seu CPF?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu CPF? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu cpf",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9720454
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=6f13315cc1444fe1836a1a283760cd23, text="Meu CPF é 42 35987-4575.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu CPF é 42 35987-4575. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu CPF é 42 35987-4575",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.269196182
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=7fe6f1b97266400fa7db871f328b50d1, text="E o seu e-mail.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E o seu e-mail. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e o seu e-mail",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.739446342
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=8def8a2a24184572b58379d166fc32d2, text="Julia@outlook.com.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Julia@outlook.com. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "julia@outlook.com",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.6963014
#   },
#   "entities": [
#     {
#       "entity": "julia@outlook.com",
#       "type": "builtin.email",
#       "startIndex": 0,
#       "endIndex": 16,
#       "resolution": {
#         "value": "julia@outlook.com"
#       }
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=8af00179faa246ca9e47525395442ba0, text="E qual seria seu telefone com DDD?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu telefone com DDD? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu telefone com ddd",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.971955538
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=8f63ae16dbd94417a34e3ce3d98d69ee, text="Meu telefone é 11 99445-8895.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu telefone é 11 99445-8895. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu telefone é 11 99445-8895",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.1746754
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=23c2c2e3fd2d41159e2ff88c8f83339e, text="Encontro aconteceu o roubo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Encontro aconteceu o roubo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "encontro aconteceu o roubo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.871490359
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=a999b504005d4ad5aaf906e4e9d9ff52, text="Rua da estrela.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Rua da estrela. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "rua da estrela",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7696607
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=ba07b916e9c24024a3228438b5e7cc5e, text="Em qual cidade?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Em qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "em qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.967263043
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=d16122eb3d3d4d5f881b2bc656f13eb4, text="São Bernardo do Campo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Bernardo do Campo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são bernardo do campo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.669091344
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=73dd206414f14c519cd1325539475189, text="Muito obrigada pelas informações você poderia anotar agora o número do protocolo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações você poderia anotar agora o número do protocolo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar agora o número do protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8945576
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=54e7807b53d0424181aeae276303c735, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8653555
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=8efb086a6bfb4aa0b88cddf2cc464c82, text="É o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: É o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "é o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.7987347
#   },
#   "entities": [
#     {
#       "entity": "54 54 5648 - 5458",
#       "type": "protocolo",
#       "startIndex": 26,
#       "endIndex": 40,
#       "score": 0.9892901
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=c8980034493244d9b8c99c36197e2c89, text="Posso ajudar em mais alguma coisa.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso ajudar em mais alguma coisa. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.96420306
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=775a0a826e5b4b16920f424f2c669806, text="Não obrigada boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não obrigada boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9349111
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4, result=IntentRecognitionResult(result_id=fbfab90bad07456881b762cfceb6cbe2, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.954223931
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# CLOSING on SessionEventArgs(session_id=9b3d2f97818c435b98be371d471e13d4)
# ok

# %% [markdown]
# ### Summarizing the classification results
# 	* Roubo: id_5
# 	* Furto:  id_1
# 	* Colisão: OK id_2
# 	* Quebra de retrovisores: OK id_3
#     * Indefinido (enchente): OK id_4

# %%
for i in results_json.keys():
    print(i)
    print (dict(Counter(tok['topScoringIntent']['intent'] for tok in results_json[i]['result'])))
# Out:
# id_1.wav
# {'None': 23, 'classe_furto': 1, 'dizer_protocolo': 1}
# id_2.wav
# {'None': 22, 'classe_colisao': 1, 'dizer_protocolo': 1}
# id_3.wav
# {'None': 22, 'classe_quebra_retrovisores': 1, 'dizer_protocolo': 1}
# id_4.wav
# {'None': 23, 'dizer_protocolo': 1}
# id_5.wav
# {'None': 22, 'classe_roubo': 1, 'dizer_protocolo': 1}

# %% [markdown]
# ## Save transcriptions locally

# %%
def save_transcriptions(dir, results_json):
    try:
        os.makedirs(dir)
    except FileExistsError:
        print ('Directory already existis: ' + dir)
        pass
    else:
        print ('Directory successfully created: ' + dir)
    for f in results_json.keys():
        file_name = re.findall(r"(.*).wav", f)[0]
        with open(os.path.join(dir, file_name + ".json"), 'w', encoding='utf-8') as j:
            json.dump(results_json[f], j, indent=4, ensure_ascii=False)
            print("Saving file {}.json".format(file_name))

# %%
save_transcriptions("transcricoes", results_json)
# Out:
# Directory successfully created: transcricoes
# Saving file id_1.json
# Saving file id_2.json
# Saving file id_3.json
# Saving file id_4.json
# Saving file id_5.json
