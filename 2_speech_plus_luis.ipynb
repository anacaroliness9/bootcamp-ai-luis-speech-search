# %% [markdown]
# # Step 2: Speech to Text with LUIS
#
# **Content**
#
# * Speech to Text with LUIS
#     * Summarizing the classification results
# * Saving transcriptions and clasifications at Azure Storage

# %%
! pip install azure-cognitiveservices-speech
# Out:
# ^C
# Requirement already satisfied: pip in c:\users\anacarolines\anaconda3\lib\site-packages (20.2.4)
# Requirement already satisfied: install in c:\users\anacarolines\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: azure-storage-blob in c:\users\anacarolines\anaconda3\lib\site-packages (12.6.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.9.0 in c:\users\anacarolines\anaconda3\lib\site-packages (from azure-storage-blob) (1.9.0)
# Requirement already satisfied: msrest>=0.6.10 in c:\users\anacarolines\anaconda3\lib\site-packages (from azure-storage-blob) (0.6.19)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\anacarolines\anaconda3\lib\site-packages (from azure-storage-blob) (3.1.1)
# Requirement already satisfied: requests>=2.18.4 in c:\users\anacarolines\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.9.0->azure-storage-blob) (2.24.0)
# Requirement already satisfied: six>=1.6 in c:\users\anacarolines\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.9.0->azure-storage-blob) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\anacarolines\anaconda3\lib\site-packages (from msrest>=0.6.10->azure-storage-blob) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anacarolines\anaconda3\lib\site-packages (from msrest>=0.6.10->azure-storage-blob) (2020.6.20)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\anacarolines\anaconda3\lib\site-packages (from msrest>=0.6.10->azure-storage-blob) (0.6.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\users\anacarolines\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.14.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\anacarolines\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.9.0->azure-storage-blob) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\anacarolines\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.9.0->azure-storage-blob) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\anacarolines\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.9.0->azure-storage-blob) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\anacarolines\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-storage-blob) (3.1.0)
# Requirement already satisfied: pycparser in c:\users\anacarolines\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.1.4->azure-storage-blob) (2.20)
# Requirement already satisfied: azure-cognitiveservices-speech in c:\users\anacarolines\anaconda3\lib\site-packages (1.14.0)

# %%
from collections import Counter
import time
import ast
import json, re
from os import listdir
import sys
import os.path

# %%
import azure.cognitiveservices.speech as speechsdk
import os, yaml, time

# %% [markdown]
# Load Configs

# %%
config_file = os.path.join("config","config.yaml")
with open(config_file, 'r') as ymlfile:
    config = yaml.load(ymlfile, Loader=yaml.FullLoader)

##### Configurações do Speech:
speech_key=config['speech']['speech_key']
speech_service_region = config['speech']['speech_region']
language=config['speech']['speech_language']

##### Configurações do LUIS
luis_app_id=config['luis_app']['app_id']

# %% [markdown]
# ## Speech to Text com LUIS

# %% [markdown]
# Referências:
# * https://github.com/Azure-Samples/cognitive-services-speech-sdk/blob/master/samples/python/console/intent_sample.py

# %%
def recognize_intent_from_speech_continuous(speech_key, speech_service_region,luis_app_id, language, file_name):
    """Método para realizar o Speech to Text integrado ao LUIS, classificando cada fala do audio com as intenções"""
    result_json = {}
    result_json['result'] = []

    # <IntentContinuousRecognitionWithFile>
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=speech_service_region, speech_recognition_language=language)
    audio_config = speechsdk.audio.AudioConfig(filename=file_name)

    # Set up the intent recognizer
    intent_recognizer = speechsdk.intent.IntentRecognizer(speech_config=speech_config, audio_config=audio_config )

    # set up the intents that are to be recognized. These can be a mix of simple phrases and
    # intents specified through a LanguageUnderstanding Model.
    model = speechsdk.intent.LanguageUnderstandingModel(app_id=luis_app_id)
    intent_recognizer.add_all_intents(model)

    # Connect callback functions to the signals the intent recognizer fires.
    done = False

    def stop_cb(evt):
        """callback that signals to stop continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        if ('SessionEventArgs' in str(evt)):
            print ("ok")
            nonlocal done
            done = True
    
    intent_recognizer.recognized.connect(lambda evt: print(
        "RECOGNIZED: {}\n\tText: {} (Reason: {})\n\tIntent Id: {}\n\tIntent JSON: {}".format(
            evt, evt.result.text, evt.result.reason, evt.result.intent_id, evt.result.intent_json, result_json['result'].append(json.loads(evt.result.intent_json)))))
    
    # cancellation event
    intent_recognizer.canceled.connect(lambda evt: print("CANCELED: {} ({})".format(evt.cancellation_details, evt.reason)))

    # stop continuous recognition on session stopped, end of speech or canceled events
    intent_recognizer.session_stopped.connect(stop_cb)
    intent_recognizer.speech_end_detected.connect(stop_cb)
    intent_recognizer.canceled.connect(stop_cb)

    # And finally run the intent recognizer. The output of the callbacks should be printed to the console.
    intent_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    intent_recognizer.stop_continuous_recognition()
    
    # </IntentContinuousRecognitionWithFile>
    return result_json

# %%
def list_files(dir):
    '''Listar arquivos em um diretório específico no SO'''
    return [f for f in os.listdir(dir) if os.path.isfile(os.path.join(dir, f))]

# %%
def realizar_transcricao_plus_intencao( container_name,files_name=None):
    ''' Realizar a transcrição + classificação das inteções de todos os audios 
        ou somente de algum específico'''
    results = {}
    if (files_name is None):
        files_name = list_files(container_name)
    for f in files_name:
        print("Processando arquivo: {}.".format(f))
        results[f] = recognize_intent_from_speech_continuous(speech_key, speech_service_region,luis_app_id, language,os.path.join(container_name, f))
    return results

# %%
######## Teste para 1 arquivo ######## 
#results_json = realizar_transcricao_plus_intencao("audios", files_name=['id_5.wav'])
# Out:
# Processando arquivo: id_5.wav.
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=5378f82eebde43adad22d163bfb70852, text="Boa tarde meu nome é Paulo para a seguradora e 6 em que eu posso te ajudar.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde meu nome é Paulo para a seguradora e 6 em que eu posso te ajudar. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde meu nome é paulo para a seguradora e 6 em que eu posso te ajudar",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.87167567
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=e03529c7b5a045fdb70e2b8c512664e9, text="Olá Paula meu nome é Julia acabei de ser assaltada e roubaram meu carro.", intent_id=classe_roubo, reason=ResultReason.RecognizedIntent))
# 	Text: Olá Paula meu nome é Julia acabei de ser assaltada e roubaram meu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: classe_roubo
# 	Intent JSON: {
#   "query": "olá paula meu nome é julia acabei de ser assaltada e roubaram meu carro",
#   "topScoringIntent": {
#     "intent": "classe_roubo",
#     "score": 0.373694479
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=5e7340473a4f40bb9362548084eaddca, text="Olá Julia eu preciso de algumas informações para registrar o seu sinistro tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Olá Julia eu preciso de algumas informações para registrar o seu sinistro tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "olá julia eu preciso de algumas informações para registrar o seu sinistro tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9624853
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=4f4d6490b73241b799997f802801bf06, text="Tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9535252
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=9ba97e7805a94150b166121ca5c37962, text="Poderia me informar a placa do seu carro.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me informar a placa do seu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me informar a placa do seu carro",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.937258
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=ea84375afa3c4b75ab10c5bcff6f7621, text="ADR 2020.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: ADR 2020. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "ADR 2020",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.666106343
#   },
#   "entities": [
#     {
#       "entity": "adr 2020",
#       "type": "placa",
#       "startIndex": 0,
#       "endIndex": 7
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=8bed9c62ec854d289eae97a384dbf3ce, text="Poderia me passar o seu nome completo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar o seu nome completo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar o seu nome completo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9342516
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=626b472b5ea340d5aba08af81b915e79, text="Meu nome completo é Júlia Silvério.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu nome completo é Júlia Silvério. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu nome completo é júlia silvério",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.2729781
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=0160ab6fb7ac4e38a899eba8b01c6c47, text="E qual seria seu CPF?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu CPF? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu cpf",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.972449362
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=30c44dace8d54ab093de05f6cec15a9d, text="Meu CPF é 42 35987-4575.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu CPF é 42 35987-4575. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu CPF é 42 35987-4575",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.3351914
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=0b53043960d341a486b4c747bade65dd, text="E o seu e-mail.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E o seu e-mail. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e o seu e-mail",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8035555
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=b92e6e98f670474796fee2c0a81da86b, text="Julia@outlook.com.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Julia@outlook.com. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "julia@outlook.com",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7101076
#   },
#   "entities": [
#     {
#       "entity": "julia@outlook.com",
#       "type": "builtin.email",
#       "startIndex": 0,
#       "endIndex": 16,
#       "resolution": {
#         "value": "julia@outlook.com"
#       }
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=9d12bf14b07f411eb22e4c8833bf0140, text="E qual seria seu telefone com DDD?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu telefone com DDD? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu telefone com ddd",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9727632
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=39a1a4e1403d45beae09a16869267211, text="Meu telefone é 11 99445-8895.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu telefone é 11 99445-8895. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu telefone é 11 99445-8895",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.227944121
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=3107e5a2789f4f648ad673cf8541c5ce, text="Encontro aconteceu o roubo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Encontro aconteceu o roubo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "encontro aconteceu o roubo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.880661964
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=cac307f0cf114b32a51a4b84a09b4f66, text="Rua da estrela.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Rua da estrela. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "rua da estrela",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7715502
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=e647303bd5f24f339bf2bad65acd0761, text="Em qual cidade?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Em qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "em qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.959405065
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=38ed075a29404ef7b3332107d94c998f, text="São Bernardo do Campo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Bernardo do Campo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são bernardo do campo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.6760082
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=6e5778bd2e4e4db0b5aa971e092d4592, text="Muito obrigada pelas informações você poderia anotar agora o número do protocolo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações você poderia anotar agora o número do protocolo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar agora o número do protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.927947
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=2cf6306f7e7e4e69913a9da1e4f07fd8, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.836006939
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=0eb5b29d56924e8bad633e2694a75ae6, text="É o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: É o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "é o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.799715042
#   },
#   "entities": [
#     {
#       "entity": "54",
#       "type": "protocolo",
#       "startIndex": 26,
#       "endIndex": 27,
#       "score": 0.848899662
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=5f690bb4dffc4be7a2c05c4ae2a3bd9a, text="Posso ajudar em mais alguma coisa.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso ajudar em mais alguma coisa. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9224346
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=931d42b27d72496c83640fafaa27415f, text="Não obrigada boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não obrigada boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9400002
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087, result=IntentRecognitionResult(result_id=08a725046d7b47a8859b5ec042bc0868, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9535252
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# CLOSING on SessionEventArgs(session_id=4295a5e68e19488d9b7d37d14ea58087)
# ok

# %%
######## Teste para todos os arquivos ######## 
results_json = realizar_transcricao_plus_intencao("audios")
# Out:
# qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "de qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.964925051
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3, result=IntentRecognitionResult(result_id=d79bbe4999354c9c8404e3f17afd9157, text="São Paulo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Paulo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são paulo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.6789285
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3, result=IntentRecognitionResult(result_id=a2c8dae6509944e1a173eeaad3bcd40a, text="Muito obrigada pelas informações você poderia anotar agora o número de protocolo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações você poderia anotar agora o número de protocolo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar agora o número de protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8974125
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3, result=IntentRecognitionResult(result_id=3f279571712a4db78d6eac23a1d2b345, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8653555
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3, result=IntentRecognitionResult(result_id=9cd2a35ba65e45b39fd1ea2d4d99eb39, text="É o número de protocolo é 540053287417.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: É o número de protocolo é 540053287417. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "é o número de protocolo é 540053287417",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.308178127
#   },
#   "entities": [
#     {
#       "entity": "540053287417",
#       "type": "protocolo",
#       "startIndex": 26,
#       "endIndex": 37,
#       "score": 0.657976866
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3, result=IntentRecognitionResult(result_id=1dc7073234d6472daa576904799e4df4, text="Irei encaminhar o seu caso para a área responsável e eles irão entrar em contato com você posso te ajudar em mais alguma coisa.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Irei encaminhar o seu caso para a área responsável e eles irão entrar em contato com você posso te ajudar em mais alguma coisa. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "irei encaminhar o seu caso para a área responsável e eles irão entrar em contato com você posso te ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8912635
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3, result=IntentRecognitionResult(result_id=6a08ef372dc648fca4c0b9d03dd1b5b5, text="Não obrigada boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não obrigada boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9349111
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3, result=IntentRecognitionResult(result_id=6d81a236cf294780894688324af4b22f, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.954223931
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# CLOSING on SessionEventArgs(session_id=9343902df57246fdb08d8bd4cae6d6e3)
# ok
# Processando arquivo: id_5.wav.
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=c3f1e6390a1c4be99d082ebd99e78079, text="Boa tarde meu nome é Paulo para a seguradora e 6 em que eu posso te ajudar.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde meu nome é Paulo para a seguradora e 6 em que eu posso te ajudar. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde meu nome é paulo para a seguradora e 6 em que eu posso te ajudar",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8615547
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=faf3f04aaf3541cbbdaddcdb9bbae9aa, text="Olá Paula meu nome é Julia acabei de ser assaltada e roubaram meu carro.", intent_id=classe_roubo, reason=ResultReason.RecognizedIntent))
# 	Text: Olá Paula meu nome é Julia acabei de ser assaltada e roubaram meu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: classe_roubo
# 	Intent JSON: {
#   "query": "olá paula meu nome é julia acabei de ser assaltada e roubaram meu carro",
#   "topScoringIntent": {
#     "intent": "classe_roubo",
#     "score": 0.315209627
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=3d03152792b14037a945f722e3664f6f, text="Olá Julia eu preciso de algumas informações para registrar o seu sinistro tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Olá Julia eu preciso de algumas informações para registrar o seu sinistro tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "olá julia eu preciso de algumas informações para registrar o seu sinistro tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.947021067
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=4ed2facb6dab4573b86de61902a165ea, text="Tudo bem.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Tudo bem. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "tudo bem",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9542239
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=b99273747641478bb28109ff047e2569, text="Poderia me informar a placa do seu carro.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me informar a placa do seu carro. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me informar a placa do seu carro",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.934775531
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=0f1febc57bee490087708589f0452b8b, text="ADR 2020.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: ADR 2020. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "ADR 2020",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.6789285
#   },
#   "entities": [
#     {
#       "entity": "adr 2020",
#       "type": "placa",
#       "startIndex": 0,
#       "endIndex": 7
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=90dbba4eaa95462d89d26c63b0e2f8f3, text="Poderia me passar o seu nome completo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Poderia me passar o seu nome completo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "poderia me passar o seu nome completo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9216928
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=aea994b853bf47639f414e35a1cccde1, text="Meu nome completo é Júlia Silvério.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu nome completo é Júlia Silvério. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu nome completo é júlia silvério",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.249826878
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=f7ff3eb4d6314e64af9bee28b776d4c6, text="E qual seria seu CPF?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu CPF? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu cpf",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9720454
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=2ab6dd13ce114efba41bf75ae0e7bdc6, text="Meu CPF é 42 35987-4575.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu CPF é 42 35987-4575. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu CPF é 42 35987-4575",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.269196182
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=3bb75b3ee08c4f67832c88089f8fd6f5, text="E o seu e-mail.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E o seu e-mail. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e o seu e-mail",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.739446342
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=9be53265b97d4e4e96741829d9995014, text="Julia@outlook.com.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Julia@outlook.com. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "julia@outlook.com",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.6963014
#   },
#   "entities": [
#     {
#       "entity": "julia@outlook.com",
#       "type": "builtin.email",
#       "startIndex": 0,
#       "endIndex": 16,
#       "resolution": {
#         "value": "julia@outlook.com"
#       }
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=43f8b8326d954fef91ae113859b051c3, text="E qual seria seu telefone com DDD?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: E qual seria seu telefone com DDD? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "e qual seria seu telefone com ddd",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.971955538
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=5fa7b9d51a664c7caa2c93e79e24cb9b, text="Meu telefone é 11 99445-8895.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Meu telefone é 11 99445-8895. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "meu telefone é 11 99445-8895",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.1746754
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=5eab6de50e624314b63c1152d534bf1e, text="Encontro aconteceu o roubo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Encontro aconteceu o roubo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "encontro aconteceu o roubo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.871490359
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=f3330bc01d76471eaff0e2d42395423c, text="Rua da estrela.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Rua da estrela. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "rua da estrela",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.7696607
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=dc88554ce3ab43cd9777eac33a9cc4c5, text="Em qual cidade?", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Em qual cidade? (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "em qual cidade",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.967263043
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=2eb67ff7be5c4b10bfebfc7022e94322, text="São Bernardo do Campo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: São Bernardo do Campo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "são bernardo do campo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.669091344
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=a48bbb06ee6e404db36df41c9c0d3604, text="Muito obrigada pelas informações você poderia anotar agora o número do protocolo.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Muito obrigada pelas informações você poderia anotar agora o número do protocolo. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "muito obrigada pelas informações você poderia anotar agora o número do protocolo",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8945576
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=ed487e7f23b84a30b30391a77ab7536d, text="Posso sim.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso sim. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso sim",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.8653555
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=7795638fc0044d878d812ebc524d438d, text="É o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você.", intent_id=dizer_protocolo, reason=ResultReason.RecognizedIntent))
# 	Text: É o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: dizer_protocolo
# 	Intent JSON: {
#   "query": "é o número de protocolo é 54 54 5648-5458 irei agora encaminhar o seu caso para área responsável e eles irão entrar em contato com você",
#   "topScoringIntent": {
#     "intent": "dizer_protocolo",
#     "score": 0.7987347
#   },
#   "entities": [
#     {
#       "entity": "54 54 5648 - 5458",
#       "type": "protocolo",
#       "startIndex": 26,
#       "endIndex": 40,
#       "score": 0.990389168
#     }
#   ]
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=e1f1b61fae844c5e9f4f56cd81953bfe, text="Posso ajudar em mais alguma coisa.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Posso ajudar em mais alguma coisa. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "posso ajudar em mais alguma coisa",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.96420306
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=476daf8e2e8045debee2f0214bf3b92a, text="Não obrigada boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Não obrigada boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "não obrigada boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.9349111
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# RECOGNIZED: IntentRecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd, result=IntentRecognitionResult(result_id=3d7578a617dc48639698f6322396e569, text="Boa tarde.", intent_id=None, reason=ResultReason.RecognizedIntent))
# 	Text: Boa tarde. (Reason: ResultReason.RecognizedIntent)
# 	Intent Id: None
# 	Intent JSON: {
#   "query": "boa tarde",
#   "topScoringIntent": {
#     "intent": "None",
#     "score": 0.954223931
#   },
#   "entities": []
# }
# CLOSING on RecognitionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# CLOSING on SessionEventArgs(session_id=f90510216b7c469a9432e3530452a7fd)
# ok

# %% [markdown]
# ### Summarizing the classification results
# 	* Roubo: id_5
# 	* Furto:  id_1
# 	* Colisão: OK id_2
# 	* Quebra de retrovisores: OK id_3
#     * Indefinido (enchente): OK id_4

# %%
for i in results_json.keys():
    print(i)
    print (dict(Counter(tok['topScoringIntent']['intent'] for tok in results_json[i]['result'])))
# Out:
# id_1.wav
# {'None': 23, 'classe_furto': 1, 'dizer_protocolo': 1}
# id_2.wav
# {'None': 22, 'classe_colisao': 1, 'dizer_protocolo': 1}
# id_3.wav
# {'None': 22, 'classe_quebra_retrovisores': 1, 'dizer_protocolo': 1}
# id_4.wav
# {'None': 23, 'dizer_protocolo': 1}
# id_5.wav
# {'None': 22, 'classe_roubo': 1, 'dizer_protocolo': 1}

# %% [markdown]
# ## Save transcriptions locally

# %%
def save_transcriptions(dir, results_json):
    try:
        os.makedirs(dir)
    except FileExistsError:
        print ('Directory already existis: ' + dir)
        pass
    else:
        print ('Directory successfully created: ' + dir)
    for f in results_json.keys():
        file_name = re.findall(r"(.*).wav", f)[0]
        with open(os.path.join(dir, file_name + ".json"), 'w', encoding='utf-8') as j:
            json.dump(results_json[f], j, indent=4, ensure_ascii=False)
            print("Saving file {}.json".format(file_name))

# %%
save_transcriptions("transcricoes", results_json)
# Out:
# Directory successfully created: transcricoes
# Saving file id_1.json
# Saving file id_2.json
# Saving file id_3.json
# Saving file id_4.json
# Saving file id_5.json
